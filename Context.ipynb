# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.text import Text
import os

# %%
texts = ['Emma', 
         'Northanger_Abbey',
         'Persuasion',
         'Mansfield_Park',
         'Pride_and_Prejudice',
         'Sense_and_Sensibility']

# %% [markdown]
# # Concordance

# %%
path = os.path.join('Corpus',f'{texts[0]}.txt')

with open( path , encoding = 'utf-8') as file:
    full_text = file.read()

tokens = word_tokenize(full_text)
novel = Text(tokens)

# %%
novel.concordance('marriage' , width = 50 , lines = 10)
# Out:
# Displaying 10 of 33 matches:
# ce of her sister ’ s marriage , been mistress of h
# ollowed Isabella ’ s marriage , on their being lef
# e knows how much the marriage is to Miss Taylor ’
#  to bring about this marriage . A worthy employmen
# e dissuaded from the marriage , and it took place
# fter a three years ’ marriage , he was rather a po
#  , even in his first marriage ; but his second mus
#  upon his father ’ s marriage , it was very genera
# ratulation which her marriage had already secured
# ince Mrs. Weston ’ s marriage her exercise had bee

# %%
import math
import re
from tdmh import *

def concordance_word( text, regex , width = 10 ):

    concordance = []
    distance = math.floor( width /2 )

    segment_length = 0

    words = word_tokenize( text )
    words = remove_punctuation( words )
    i = 0
    for w in words:
        if re.search( regex , w , re.IGNORECASE ):
            match = ''
            for x in range( i - distance , ( i + distance ) + 1 ):
                if x >= 0 and x < len(words):
                    if len(words[x]) >= 0:
                        match += words[x] + ' '
            concordance.append( match )

        i += 1

    return concordance

# %%
with open( path , encoding = 'utf-8') as file:
    full_text = file.read()
    
fragments = concordance_word( full_text , r'marriage' , 16)

print( f'There are {len(fragments)} ocurrences of the word "marriage".')

number_of_results = 5

print( f'Here are the first {number_of_results} occurrences:\n\n')
for f in fragments[:number_of_results]:
    print( f'{f}\n')
# Out:
# There are 34 ocurrences of the word "marriage".
# Here are the first 5 occurrences:
#
#
# and had in consequence of her sister s marriage been mistress of his house from a very
#
# perfect unreserve which had soon followed Isabella s marriage on their being left to each other was
#
# suppose it but she knows how much the marriage is to Miss Taylor s advantage she knows
#
# the last four years to bring about this marriage A worthy employment for a young lady s
#
# to the not to be dissuaded from the marriage and it took place to the infinite mortification

# %%
fragments = concordance_word(full_text , r'(\bhates?\b)|(\bloves?\b)' , 25)

for f in fragments:
    print( f'{f}\n')
# Out:
# you What a horrible idea Oh no I meant only myself Knightley loves to find fault with me you a is all a joke We
#
# Miss Churchill of a great Yorkshire family and Miss Churchill fell in love with him nobody was surprized except her brother and his wife who
#
# due to her in return for the great goodness of being in love with him but though she had one sort of spirit she had
#
# it was nothing in comparison of Enscombe she did not cease to love her husband but she wanted at once to be the wife of
#
# intellectual superiority to make atonement to herself or frighten those who might hate her into outward respect She had never boasted either beauty or cleverness
#
# through the fluctuations of this speech and saw no alarming symptoms of love The young man had been the first admirer but she trusted there
#
# with her person he replied I think her all you describe I love to look at her and I will add this praise that I
#
# keep my spleen to myself till Christmas brings John and Isabella John loves Emma with a reasonable and therefore not a blind affection and Isabella
#
# am sure of having their opinions with I know that you all love her really too well to be unjust or unkind but excuse me
#
# not be a bad thing for her to be very much in love with a proper object I should like to see Emma in love
#
# love with a proper object I should like to see Emma in love and in some doubt of a return it would do her good
#
# convinced of Elton s being in the fairest way of falling in love if not in love already She had no scruple with regard to
#
# being in the fairest way of falling in love if not in love already She had no scruple with regard to him He talked of
#
# before it was possible She could not respect his eye but his love and his complaisance were unexceptionable The sitting was altogether very satisfactory she
#
# he received it This man is almost too gallant to be in love thought Emma I should say so but that I suppose there may
#
# I suppose there may be a hundred different ways of being in love He is an excellent young man and will suit Harriet exactly it
#
# still smiling Very serious I can think of but one is in love with her Who makes you their confidant Emma was more than half
#
# this summer seems to have done his business He is desperately in love and means to marry He is very obliging said Emma but is
#
# do worse But I could not reason so to a man in love and was willing to trust to there being no harm in her
#
# of beauty than they are generally supposed till they do fall in love with minds instead of handsome faces a girl with such loveliness as
#
# best known to yourself but as you make no secret of your love of it is fair to suppose that views and plans and projects
#
# ready wit All the better A man must be very much in love indeed to describe her so Ah Knightley I wish you had the
#
# seem to be a something in the air of Hartfield which gives love exactly the right direction and sends it into the very channel where
#
# the very channel where it ought to flow The course of true love never did run A Hartfield edition of Shakespeare would have a long
#
# have a long note on that That Elton should really be in love with me of all people who did not know him to speak
#
# world which must satisfy Yes very true How nicely you talk I love to hear you You understand every thing You and Elton are one
#
# have his charade slighted much better than his passion A poet in love must be encouraged in both capacities or neither Give me the book
#
# quite sure that her friend were not writing down a declaration of love It seemed too precious an offering for any degree of publicity I
#
# charade to him It will be giving him so much pleasure He loves any thing of the sort and especially any thing that pays woman
#
# exteriors and probabilities Emma could only class it as a proof of love with Elton s seeing ready wit in her I wish we could
#
# the usual inducements of women to marry Were I to fall in love indeed it would be a different thing but I never have been
#
# it would be a different thing but I never have been in love it is not my way or my nature and I do not
#
# my nature and I do not think I ever shall And without love I am sure I should be a fool to change such a
#
# be very well off with all the children of a sister I love so much to care about There will be enough of them in
#
# meet in a charitable scheme this will bring a great increase of love on each side I should not wonder if it were to bring
#
# of course was her consoling reflection any thing interests between those who love and any thing will serve as introduction to what is near the
#
# her father and sister that but for these higher ties a warmer love might have seemed impossible She could never see a fault in any
#
# man makes it all easy I have been always telling you my love that I had no idea of the change being so very material
#
# of putting all the Westons aside as much as she Me my love cried his wife hearing and understanding only in Are you talking about
#
# John Knightley hearing his own name I am sorry to find my love that my father does not think you looking I hope it is
#
# a most valuable amiable pleasing young man undoubtedly and very much in love with Harriet but still he can not refuse an invitation he must
#
# he must dine out wherever he is asked What a strange thing love is he can see ready wit in Harriet but will not dine
#
# before you may as well take it into consideration Mr Elton in love with me an idea I do not say it is so but
#
# was in the habit of receiving to emulate the Very true my love which must have been usually administered by his travelling companion but she
#
# vexed It did was no concealing like the pretence of being in love with her instead of Harriet an inconstancy if real the most contemptible
#
# that might impede them You had better order the carriage directly my love said she I dare say we shall be able to get along
#
# found her subject cut hand attention demanded and Elton actually making violent love to her availing himself of the precious opportunity declaring sentiments which must
#
# she refused him but flattering himself that his ardent attachment and unequalled love and unexampled passion could not fail of having some effect and in
#
# the arrogance to raise his eyes to her pretended to be in love but she was perfectly easy as to his not suffering any disappointment
#
# of expressions or fancy any tone of voice less allied with real love She need not trouble herself to pity him He only wanted to
#
# to notice but his situation and his he had fancied her in love with him that evidently must have been his dependence and after raving
#
# It was a great consolation that Elton should not be really in love with her or so particularly amiable as to make it shocking to
#
# him in person or did in truth prove herself more resolutely in love than Emma had foreseen but yet it appeared to her so natural
#
# am very much and without being at all ashamed of it My love for and Weston gives me a decided prejudice in his He is
#
# thing mischievous which her imagination had suggested at first If it were love it might be simple single successless love on her side alone She
#
# at first If it were love it might be simple single successless love on her side alone She might have been unconsciously sucking in the
#
# blessed in our dear sir if there is one thing my mother loves better than another it is roast loin of As to who or
#
# be sorry to lose must be all sorry Ambition as well as love had probably been mortified They might all have hoped to rise by
#
# given Harriet her feelings about it all She had talked her into love but alas she was not so easily to be talked out of
#
# was one of those who having once begun would be always in love And now poor girl she was considerably worse from this reappearance of
#
# his hat being all in proof of how much he was in love Had it been allowable entertainment had there been no pain to her
#
# being thought to play well man a very musical man and in love with another to the point of yet never ask that other woman
#
# pleasing There is safety in reserve but no attraction One can not love a reserved Not till the reserve ceases towards oneself and then the
#
# which she had believed herself to discern in him yesterday Vanity extravagance love of change restlessness of temper which must be doing something good or
#
# imagination had given him the honour if not of being really in love with her of being at least very near it and saved only
#
# and style of living second only to the family at Hartfield Their love of society and their new prepared every body for their keeping and
#
# me to come away before I am tired papa Oh no my love but you will soon be tired There will be a great many
#
# am not afraid of your not being exceedingly comfortable with Goddard She loves piquet you know but when she is gone home I am afraid
#
# she could wish for When the Westons arrived the kindest looks of love the strongest of admiration were for her from both husband and wife
#
# his proposals to her friend he had the misfortune to fall in love with her or that he became conscious of a little attachment on
#
# could not exult in her dignity and grace she could not only love the blooming sweetness and the artless manner but could most heartily rejoice
#
# begun to enjoy myself But just got acquainted with Weston and others hate the Perhaps you may now begin to regret that you spent one
#
# long as he thinks so it is so but if he really loves Jane Nonsense He does not care about Jane Fairfax In the way
#
# Nonsense He does not care about Jane Fairfax In the way of love I am sure he does not He would do any good to
#
# Then it can be no argument to prove that he is in love But I do not think it is at all a likely thing
#
# not know she had any taste Nobody talked about it And I hate Italian is no understanding a word of it Besides if she does
#
# a great deal of friendly and of compassionate attachment on his no love Alas there was soon no leisure for quarrelling with Knightley Two days
#
# warm He stopt again rose again and seemed quite was more in love with her than Emma had supposed and who can say how it
#
# the rest made her think that she must be a little in love with him in spite of every previous determination against it I certainly
#
# s being dull and insipid about the house I must be in love I should be the oddest creature in the world if I were
#
# CHAPTER XIII Emma continued to entertain no doubt of her being in love Her ideas only varied as to the how much At first she
#
# this it struck her that she could not be very much in love for in spite of her previous and fixed determination never to quit
#
# myself to feel more than I do I am quite enough in love I should be sorry to be Upon the whole she was equally
#
# his feelings He is undoubtedly very much in thing denotes much in love indeed when he comes again if his affection continue I must be
#
# be a good thing over for they say every body is in love once in their lives and I shall have been let off When
#
# it is not every man s fate to marry the woman who loves him best Miss Hawkins perhaps wanted a home and thought this the
#
# from the house I absolutely must go in by myself though I hate being stuck up in the without a companion but Augusta I believe
#
# She is reserved more reserved I think than she used to I love an open temper Cole alluded to my supposed attachment it had never
#
# is so very much occupied by the idea of not being in love with her that I should not wonder if it were to end
#
# if he who had undoubtedly been always so much the most in love of the two were to be returning with the same warmth of
#
# watched him well It was a clear thing he was less in love than he had been Absence with the conviction probably of her indifference
#
# smile but in general he was looking grave She wished he could love a ballroom better and could like Frank Churchill seemed often observing her
#
# not forestall Jane I left her dancing with George Otway she will love to tell you all about it herself her first partner was Elton
#
# boiled enough sent it all out again Now there is nothing grandmama loves better than sweetbread and she was rather disappointed but we agreed we
#
# I did not and I was fully convinced of his being in love with Harriet It was through a series of strange blunders And in
#
# neglect that could be farther rational Frank Churchill not too much in love and Knightley not wanting to quarrel with her how very happy a
#
# not It was done however This gallant young man who seemed to love without feeling and to recommend himself without complaisance directly handed over the
#
# her father saying in I am glad I have done being in love with him I should not like a man who is so soon
#
# chiefly to her husband and he murmured in reply Very true my love very true Exactly so unheard some ladies say any thing Better pass
#
# and Isabella Have you any thing to send or say besides the love which nobody carries Nothing at all But is not this a sudden
#
# doing could he tell that he might not be making me in love with him wrong very wrong From something that he said my dear
#
# in a hurry to condemn him Let us have patience I must love him and now that I am satisfied on one point the one
#
# to my ear when you imagined a certain friend of ours in love with the True But as I have always had a thoroughly good
#
# to speak Had you any idea cried Harriet of his being in love with her perhaps blushing as she spoke who can see into every
#
# truth Why was it so much worse that Harriet should be in love with Knightley than with Frank Churchill Why was the evil so dreadfully
#
# making the story known to Colonel Poor girl said Emma again She loves him then excessively I suppose It must have been from attachment only
#
# I must often have contributed to make her On your side my love it was very innocently done But she probably had something of that
#
# felicity that man in all human calculation has before him of the love of such a disinterested love for Jane Fairfax s character vouches for
#
# human calculation has before him of the love of such a disinterested love for Jane Fairfax s character vouches for her disinterestedness every thing in
#
# as the arrival or even the expectation of Frank had been in love with Emma and jealous of Frank Churchill from about the same period
#
# as to long to have her as deeply and as happily in love as strange things I said or did during that fortnight you have
#
# for the writer and the very strong attraction which any picture of love must have for her at that moment She never stopt till she
#
# was very he was so grateful to Weston and so much in love with Miss Fairfax and she was so happy herself that there was
#
# head a word or two of assent or disapprobation or merely of love as the subject required concluding however seriously and after steady reflection Very
#
# English such as Knightley used even to the woman he was in love with how to be able to ask her to marry him without
#
# too much to hope even of Harriet that she could be in love with more than three men in one year CHAPTER XVI It was
#
# what I wanted to be assured if you knew how much I love every thing that is decided and open CHAPTER XVII Weston s friends
#
# all and by dint of fancying so many errors have been in love with you ever since you were thirteen at I am sure you
#
# much for her as you have done for me except falling in love with her when she is How often when you were a girl
#
# at hand when he were once got used to the he not love Knightley very much would not deny that he did she was did
#
# him and after observing her a little while he added Emma my love you said that this circumstance would not now make you unhappy but
#
# sake whom I have always had reason to believe as much in love with her as ever to get acquainted with her I have often
#
# that Harriet had always liked Robert Martin and that his continuing to love her had been this it must ever be unintelligible to Emma The

# %%
def collocation( text , regex , width ):

    freq_c = dict()
    distance = math.floor(width/2)

    sentences = sent_tokenize( text )

    for sentence in sentences:

        words = word_tokenize( sentence )
        words = remove_punctuation(words)

        for i,w in enumerate(words):
            if re.search( regex , w , re.IGNORECASE ):
                index_regex = i 

                for x in range( i - distance , i + distance ):
                    if x >= 0 and x < len(words) and words[x].lower() != words[index_regex].lower():
                        if len(words[x]) > 0:
                            word = words[x].lower()
                            freq_c[ word ] = freq_c.get( word , 0 ) + 1
            
    return freq_c

# %%
nearby_words = collocation( full_text , r'marriage' , 20)

from nltk.corpus import stopwords
stopwords = stopwords.words('english')

nearby_words_sorted = sortedByValue( nearby_words , ascending = False)

for word in list( nearby_words_sorted.keys() ):
    freq = nearby_words_sorted[word]
    if word not in stopwords and freq > 1:
        print( f'{word} => {freq}')
# Out:
# every => 5
# since => 4
# miss => 4
# father => 4
# till => 3
# martin => 3
# must => 3
# much => 3
# isabella => 3
# soon => 3
# emma => 2
# might => 2
# elton => 2
# never => 2
# however => 2
# hartfield => 2
# find => 2
# event => 2
# offer => 2
# smith => 2
# harriet => 2
# quite => 2
# proposal => 2
# weston => 2
# year => 2
# proposed => 2
# secured => 2
# first => 2
# man => 2
# place => 2
# years => 2
# knows => 2
# yet => 2

# %% [markdown]
# # Coorccurrence

# %%
def cooccurrence( text , word1 , word2 , width ):
    
    relevant_sentences = []
    
    text = re.sub( '\s+' , ' ' , text )
    sentences = sent_tokenize( text )

    for s in sentences:
        if re.search( r'\b' + word1 + r'\b' , s , re.IGNORECASE ) and re.search( r'\b' + word2 + r'\b' , s , re.IGNORECASE ):

            words = word_tokenize(s)
            word1_indexes = []
            word2_indexes = []
            
            for i,w in enumerate(words):
                if re.search( r'\b' + word1 + r'\b' , w , re.IGNORECASE ):
                    word1_indexes.append(i)
                elif re.search( r'\b' + word2 + r'\b' , w , re.IGNORECASE ):
                    word2_indexes.append(i)

            if word1_indexes[0] > word2_indexes[0]:
                difference = word1_indexes[0] - word2_indexes[0]
            else:
                difference = word2_indexes[0] - word1_indexes[0]

            if difference <= width:
                relevant_sentences.append(s)
    return relevant_sentences

# %%
sentences = cooccurrence( full_text , 'marriage' , 'lydia' , 10 )

for s in sentences:
    print( f'{s}\n')
